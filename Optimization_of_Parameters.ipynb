# %%
m_values = np.unique(np.linspace(9000, 10000, 100).round().astype(int)).tolist()
n_values = np.unique(np.linspace(400, 1000, 100).round().astype(int)).tolist()
k_values = np.linspace(2, 10, 5, dtype=int).tolist()
ell_values = np.linspace(2, 10, 9, dtype=int).tolist()
eps_values = np.linspace(0.1, 0.3, 5).tolist()
kappa_values = np.linspace(0.5, 1.0, 5).tolist()
