# %%
import sys
from pathlib import Path

ROOT = Path.cwd()
while ROOT != ROOT.parent and not (ROOT / "kxor_code").exists():
    ROOT = ROOT.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

OUT_DIR = ROOT / "data" / "problem_instances"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("Project root:", ROOT)
print("Output directory:", OUT_DIR)
# Out:
# Project root: /Users/daphnejanissen/Documents/DSDM/Quantum Research Project/QuarticSpeedupK-XOR
# Output directory: /Users/daphnejanissen/Documents/DSDM/Quantum Research Project/QuarticSpeedupK-XOR/data/problem_instances

# %%
m_values     = np.linspace(1, 100000, 100000, dtype=int).tolist()
n_values     = np.linspace(1, 50000, 50000, dtype=int).tolist()
k_values     = np.linspace(2, 10, 9, dtype=int).tolist()
ell_values   = np.linspace(2, 10, 5, dtype=int).tolist()
eps_values   = np.linspace(0.1, 0.3, 5).tolist()
kappa_values = np.linspace(0.5, 1.0, 5).tolist()

# %%
import math
from bisect import bisect_left
from math import comb
from kxor_code.problem_set_generation.kikuchi_matrix_generator import *

def brute_force_problem_parameter_search(
    n_values: list[int], k_values: list[int], ell_values: list[int],
    eps_values: list[float], kappa_values: list[float], m_values: list[int],
    n_factor: int = 100
):
    results = []
    m_sorted = sorted(m_values)

    for n in n_values:
        for k in k_values:
            for ell in ell_values:
                for eps in eps_values:
                    for kappa in kappa_values:

                        # ---- structural constraints (same as in check_alice_theorem) ----
                        if k <= 0 or k % 2 != 0:
                            continue
                        if ell < k / 2:
                            continue
                        if not (0 < kappa <= 1):
                            continue
                        if not (0 < eps <= kappa / (2 + kappa)):
                            continue
                        if n_factor is not None and n < n_factor * k * ell:
                            continue

                        # ---- compute the Delta threshold ----
                        C_kappa = (
                            2 * (1 + eps) * (1 + kappa) / (kappa ** 2)
                            * (1 / comb(k, k // 2))
                            * math.log(n)
                        )
                        delta_threshold = C_kappa * (n / ell) ** ((k - 2) / 2)

                        # Delta = m/n >= threshold  ->  m >= n * threshold
                        m_required = math.ceil(n * delta_threshold)

                        # ---- pick smallest allowed m that satisfies it ----
                        idx = bisect_left(m_sorted, m_required)
                        if idx == len(m_sorted):
                            continue
                        m = m_sorted[idx]

                        # ---- verify using your original theorem checker ----
                        r = check_alice_theorem(
                            ell=ell, n=n, k=k, kappa=kappa, eps=eps, m=m,
                            n_factor=n_factor
                        )

                        if not r["failure"]:
                            # IMPORTANT: add back the inputs so you can sort/print them
                            r.update({"n": n, "k": k, "ell": ell, "eps": eps, "kappa": kappa, "m": m})
                            results.append(r)

    return results

# %%
results = brute_force_problem_parameter_search(
    n_values=n_values,
    k_values=k_values,
    ell_values=ell_values,
    eps_values=eps_values,
    kappa_values=kappa_values,
    m_values=m_values,
    n_factor=4
)

print(f"Found {len(results)} feasible parameter sets")
# Out:
# Found 376715 feasible parameter sets

# %%
best = min(results, key=lambda r: (r["n"], r["m"]))

print("\nBEST (smallest n, m):")
print(f"n      = {best['n']}")
print(f"m      = {best['m']}")
print(f"k      = {best['k']}")
print(f"ell    = {best['ell']}")
print(f"kappa  = {best['kappa']}")
print(f"eps    = {best['eps']}")
print(f"Delta  = {best['Delta']:.4f}")
print(f"Delta_threshold = {best['Delta_threshold']:.4f}")
print(f"n / (k·ell) = {best['n_over_k_l']:.2f}")
print(f"Failure prob ≤ {best['failure_probability_bound']:.2e}")
# Out:
# BEST (smallest n, m):
# n      = 16
# m      = 98
# k      = 2
# ell    = 2
# kappa  = 1.0
# eps    = 0.1
# Delta  = 6.1250
# Delta_threshold = 6.0997
# n / (k·ell) = 4.00
# Failure prob ≤ 1.72e+00

# %%
import math

# Failure probability bound
P_MAX = 0.1  

good = [r for r in results if r["failure_probability_bound"] <= P_MAX]

if not good:
    print(f"No feasible sets with failure_probability_bound <= {P_MAX}.")
else:
    best = min(good, key=lambda r: (r["n"], r["m"], r["k"], r["ell"]))

    print(f"Found {len(good)} feasible sets with failure prob bound <= {P_MAX}\n")
    print("BEST (smallest n, m) under failure-prob constraint:")
    print(f"n      = {best['n']}")
    print(f"m      = {best['m']}")
    print(f"k      = {best['k']}")
    print(f"ell    = {best['ell']}")
    print(f"kappa  = {best['kappa']}")
    print(f"eps    = {best['eps']}")
    print(f"Delta  = {best['Delta']:.4f}")
    print(f"Delta_threshold = {best['Delta_threshold']:.4f}")
    print(f"n / (k·ell) = {best['n_over_k_l']:.2f}")
    print(f"Failure prob ≤ {best['failure_probability_bound']:.2e}")
# Out:
# Found 295571 feasible sets with failure prob bound <= 0.1
#
# BEST (smallest n, m) under failure-prob constraint:
# n      = 32
# m      = 278
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.6875
# Delta_threshold = 8.6643
# n / (k·ell) = 4.00
# Failure prob ≤ 9.38e-02

# %%
small_n_sets = [r for r in results if r["n"] < 37 and r["failure_probability_bound"] < 0.10]

print(f"Found {len(small_n_sets)} parameter sets with n < 37\n")

for i, r in enumerate(small_n_sets, 1):
    print(f"--- Set {i} ---")
    print(f"n      = {r['n']}")
    print(f"m      = {r['m']}")
    print(f"k      = {r['k']}")
    print(f"ell    = {r['ell']}")
    print(f"kappa  = {r['kappa']}")
    print(f"eps    = {r['eps']}")
    print(f"Delta  = {r['Delta']:.4f}")
    print(f"Delta_threshold = {r['Delta_threshold']:.4f}")
    print(f"n / (k·ell) = {r['n_over_k_l']:.2f}")
    print(f"Failure prob ≤ {r['failure_probability_bound']:.2e}")
    print()
# Out:
# Found 25 parameter sets with n < 37
#
# --- Set 1 ---
# n      = 32
# m      = 432
# k      = 2
# ell    = 4
# kappa  = 0.75
# eps    = 0.25
# Delta  = 13.5000
# Delta_threshold = 13.4779
# n / (k·ell) = 4.00
# Failure prob ≤ 9.38e-02
#
# --- Set 2 ---
# n      = 32
# m      = 340
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.25
# Delta  = 10.6250
# Delta_threshold = 10.6094
# n / (k·ell) = 4.00
# Failure prob ≤ 9.38e-02
#
# --- Set 3 ---
# n      = 32
# m      = 278
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.6875
# Delta_threshold = 8.6643
# n / (k·ell) = 4.00
# Failure prob ≤ 9.38e-02
#
# --- Set 4 ---
# n      = 32
# m      = 354
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.3
# Delta  = 11.0625
# Delta_threshold = 11.0338
# n / (k·ell) = 4.00
# Failure prob ≤ 4.69e-02
#
# --- Set 5 ---
# n      = 32
# m      = 289
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.3
# Delta  = 9.0312
# Delta_threshold = 9.0109
# n / (k·ell) = 4.00
# Failure prob ≤ 4.69e-02
#
# --- Set 6 ---
# n      = 33
# m      = 449
# k      = 2
# ell    = 4
# kappa  = 0.75
# eps    = 0.25
# Delta  = 13.6061
# Delta_threshold = 13.5975
# n / (k·ell) = 4.12
# Failure prob ≤ 9.09e-02
#
# --- Set 7 ---
# n      = 33
# m      = 354
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.25
# Delta  = 10.7273
# Delta_threshold = 10.7036
# n / (k·ell) = 4.12
# Failure prob ≤ 9.09e-02
#
# --- Set 8 ---
# n      = 33
# m      = 289
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.7576
# Delta_threshold = 8.7413
# n / (k·ell) = 4.12
# Failure prob ≤ 9.09e-02
#
# --- Set 9 ---
# n      = 33
# m      = 368
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.3
# Delta  = 11.1515
# Delta_threshold = 11.1317
# n / (k·ell) = 4.12
# Failure prob ≤ 4.52e-02
#
# --- Set 10 ---
# n      = 33
# m      = 301
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.3
# Delta  = 9.1212
# Delta_threshold = 9.0909
# n / (k·ell) = 4.12
# Failure prob ≤ 4.52e-02
#
# --- Set 11 ---
# n      = 34
# m      = 467
# k      = 2
# ell    = 4
# kappa  = 0.75
# eps    = 0.25
# Delta  = 13.7353
# Delta_threshold = 13.7136
# n / (k·ell) = 4.25
# Failure prob ≤ 8.82e-02
#
# --- Set 12 ---
# n      = 34
# m      = 368
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.25
# Delta  = 10.8235
# Delta_threshold = 10.7950
# n / (k·ell) = 4.25
# Failure prob ≤ 8.82e-02
#
# --- Set 13 ---
# n      = 34
# m      = 300
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.8235
# Delta_threshold = 8.8159
# n / (k·ell) = 4.25
# Failure prob ≤ 8.82e-02
#
# --- Set 14 ---
# n      = 34
# m      = 382
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.3
# Delta  = 11.2353
# Delta_threshold = 11.2268
# n / (k·ell) = 4.25
# Failure prob ≤ 4.36e-02
#
# --- Set 15 ---
# n      = 34
# m      = 312
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.3
# Delta  = 9.1765
# Delta_threshold = 9.1685
# n / (k·ell) = 4.25
# Failure prob ≤ 4.36e-02
#
# --- Set 16 ---
# n      = 35
# m      = 484
# k      = 2
# ell    = 4
# kappa  = 0.75
# eps    = 0.25
# Delta  = 13.8286
# Delta_threshold = 13.8264
# n / (k·ell) = 4.38
# Failure prob ≤ 8.57e-02
#
# --- Set 17 ---
# n      = 35
# m      = 381
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.25
# Delta  = 10.8857
# Delta_threshold = 10.8837
# n / (k·ell) = 4.38
# Failure prob ≤ 8.57e-02
#
# --- Set 18 ---
# n      = 35
# m      = 312
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.9143
# Delta_threshold = 8.8884
# n / (k·ell) = 4.38
# Failure prob ≤ 8.57e-02
#
# --- Set 19 ---
# n      = 35
# m      = 397
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.3
# Delta  = 11.3429
# Delta_threshold = 11.3191
# n / (k·ell) = 4.38
# Failure prob ≤ 4.21e-02
#
# --- Set 20 ---
# n      = 35
# m      = 324
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.3
# Delta  = 9.2571
# Delta_threshold = 9.2439
# n / (k·ell) = 4.38
# Failure prob ≤ 4.21e-02
#
# --- Set 21 ---
# n      = 36
# m      = 502
# k      = 2
# ell    = 4
# kappa  = 0.75
# eps    = 0.25
# Delta  = 13.9444
# Delta_threshold = 13.9359
# n / (k·ell) = 4.50
# Failure prob ≤ 8.33e-02
#
# --- Set 22 ---
# n      = 36
# m      = 395
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.25
# Delta  = 10.9722
# Delta_threshold = 10.9700
# n / (k·ell) = 4.50
# Failure prob ≤ 8.33e-02
#
# --- Set 23 ---
# n      = 36
# m      = 323
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.25
# Delta  = 8.9722
# Delta_threshold = 8.9588
# n / (k·ell) = 4.50
# Failure prob ≤ 8.33e-02
#
# --- Set 24 ---
# n      = 36
# m      = 411
# k      = 2
# ell    = 4
# kappa  = 0.875
# eps    = 0.3
# Delta  = 11.4167
# Delta_threshold = 11.4088
# n / (k·ell) = 4.50
# Failure prob ≤ 4.07e-02
#
# --- Set 25 ---
# n      = 36
# m      = 336
# k      = 2
# ell    = 4
# kappa  = 1.0
# eps    = 0.3
# Delta  = 9.3333
# Delta_threshold = 9.3171
# n / (k·ell) = 4.50
# Failure prob ≤ 4.07e-02

# %%
import pickle

with open("theorem_results.pkl", "wb") as f:
    pickle.dump(results, f)
